# %%
import papermill as pm

pm.execute_notebook(
   'Grafica1.ipynb',
   'Reporte.ipynb',
   parameters=dict(dinicial=1, minicial=1, dfinal=25, mfinal=2)
)
# Out:
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'cloudy-compact',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-05-12T09:35:09.657680',
#      'end_time': '2021-05-12T09:35:11.219595',
#      'duration': 1.561915,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-05-12T09:35:09.694872Z',
#      'iopub.execute_input': '2021-05-12T09:35:09.702888Z',
#      'iopub.status.idle': '2021-05-12T09:35:11.219595Z',
#      'shell.execute_reply': '2021-05-12T09:35:11.219595Z'}},
#    'outputs': [],
#    'source': '#importar las librerias necesarias\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport pandas as pd'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': 'thousand-poetry',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-05-12T09:35:11.237310',
# ...

# %%
import papermill as pm

pm.execute_notebook(
   'Grafica2.ipynb',
   'Reporte2.ipynb',
   parameters=dict(dinicial=19, minicial=1, dfinal=8, mfinal=4)
)
# Out:
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'increased-italian',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-05-12T09:35:15.976902',
#      'end_time': '2021-05-12T09:35:17.852331',
#      'duration': 1.875429,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-05-12T09:35:15.998465Z',
#      'iopub.execute_input': '2021-05-12T09:35:15.998465Z',
#      'iopub.status.idle': '2021-05-12T09:35:17.852331Z',
#      'shell.execute_reply': '2021-05-12T09:35:17.852331Z'}},
#    'outputs': [],
#    'source': '#importar las librerias necesarias\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport pandas as pd\nfrom datetime import timedelta, date'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': 'critical-looking',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
# ...

# %%
import papermill as pm

pm.execute_notebook(
   'Grafica3.ipynb',
   'Reporte3.ipynb',
   parameters=dict(dinicial=19, minicial=1, dfinal=18, mfinal=3)
)
# Out:
# Executing:   0%|          | 0/6 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'fourth-behavior',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-05-12T09:41:54.286117',
#      'end_time': '2021-05-12T09:41:55.756639',
#      'duration': 1.470522,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-05-12T09:41:54.314871Z',
#      'iopub.execute_input': '2021-05-12T09:41:54.314871Z',
#      'iopub.status.idle': '2021-05-12T09:41:55.756639Z',
#      'shell.execute_reply': '2021-05-12T09:41:55.756639Z'}},
#    'outputs': [],
#    'source': '#importar las librerias necesarias\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport pandas as pd\nfrom datetime import timedelta, date'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': 'medical-hostel',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
# ...
